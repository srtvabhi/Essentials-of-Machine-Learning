# %%
print(5*3)
# Out:
# 15

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# to check and package version
# !pip show pandas

# %% [markdown]
# ### read dataset

# %%
df =  pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### to print summary of my data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   768 non-null    int64
#  1   BloodPressure             768 non-null    int64
#  2   SkinThickness             768 non-null    int64
#  3   Insulin                   768 non-null    int64
#  4   BMI                       768 non-null    float64
#  5   DiabetesPedigreeFunction  768 non-null    float64
#  6   Age                       768 non-null    int64
#  7   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 48.1 KB

# %%
# to print row

print('Rows : ',df.shape[0])
# Out:
# Rows :  768

# %%
print('Column : ',df.shape[1])
# Out:
# Column :  8

# %%
# print the column name
df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# to check the null value 
# function name is:  isnull()
# if any null value is there this will return true , otherwise False
df.isnull()
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0      False          False          False    False  False
# 1      False          False          False    False  False
# 2      False          False          False    False  False
# 3      False          False          False    False  False
# 4      False          False          False    False  False
# ..       ...            ...            ...      ...    ...
# 763    False          False          False    False  False
# 764    False          False          False    False  False
# 765    False          False          False    False  False
# 766    False          False          False    False  False
# 767    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# ...

# %%
# give me count of null value in each column 
df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# to check in a coulmn how many unique value are there
df.nunique()
# Out:
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
# you want otcheck what are those unique value 
df['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190])

# %%
df['Outcome'].unique()
# Out:
# array([1, 0])

# %%
# stats value for each column - mean , median mode
df.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   120.894531      69.105469      20.536458   79.799479   31.992578
# std     31.972618      19.355807      15.952218  115.244002    7.884160
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      62.000000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.240885    0.348958
# std                    0.331329   11.760232    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %%
# plotting
# you want plot histogram on glucose column 

df['Glucose'].hist(bins=10)
plt.show()

# %%
df['Glucose'].hist(bins=15)
plt.show()

# %%
df['Outcome'].hist(bins=15)
plt.show()

# %%
# pair plot : this create charts with all other column

sns.pairplot(data=df)
plt.show()

# %%
#box plot  : is use to check data range (min 25% , 50% , 75 % max)

sns.boxplot(x = df['BMI'])
plt.show()

# %%
# vertical box plot 
sns.boxplot(y = df['BMI'])
plt.show()

# %%
# objective i need to check BMI of diabetic and non diabetic 
sns.boxplot( y = df['BMI'],hue = df['Outcome'])
plt.show()

# %%
# corelation
corr = df.corr()
corr
# Out:
#                            Glucose  BloodPressure  SkinThickness   Insulin  \
# Glucose                   1.000000       0.152590       0.057328  0.331357
# BloodPressure             0.152590       1.000000       0.207371  0.088933
# SkinThickness             0.057328       0.207371       1.000000  0.436783
# Insulin                   0.331357       0.088933       0.436783  1.000000
# BMI                       0.221071       0.281805       0.392573  0.197859
# DiabetesPedigreeFunction  0.137337       0.041265       0.183928  0.185071
# Age                       0.263514       0.239528      -0.113970 -0.042163
# Outcome                   0.466581       0.065068       0.074752  0.130548
#
#                                BMI  DiabetesPedigreeFunction       Age  \
# Glucose                   0.221071                  0.137337  0.263514
# BloodPressure             0.281805                  0.041265  0.239528
# SkinThickness             0.392573                  0.183928 -0.113970
# ...

# %%
# heat map
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True)
plt.show()

# %%
# value count in each coumnn
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# group mean()
df.groupby('Outcome').mean()
# Out:
#             Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Outcome
# 0        109.980000      68.184000      19.664000   68.792000  30.304200
# 1        141.257463      70.824627      22.164179  100.335821  35.142537
#
#          DiabetesPedigreeFunction        Age
# Outcome
# 0                        0.429734  31.190000
# 1                        0.550500  37.067164

# %%
# sort 
df.sort_values(by='Glucose', ascending=False)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661      199             76             43        0  42.9
# 561      198             66             32      274  41.3
# 579      197             70             99        0  34.7
# 228      197             70             39      744  36.7
# 8        197             70             45      543  30.5
# ..       ...            ...            ...      ...   ...
# 182        0             74             20       23  27.7
# 342        0             68             35        0  32.0
# 349        0             80             32        0  41.0
# 75         0             48             20        0  24.7
# 502        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1
# 561                     0.502   28        1
# 579                     0.575   62        1
# 228                     2.329   31        0
# ...
